# %% [markdown]
# <a href="https://colab.research.google.com/github/kimo722504/practice_ML/blob/master/run_image_embedding_v0_0_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tag 0.0.1
# Notice : **Change** runtime type from None to **TPU**

# %%
# !git clone https://github.com/elangovana/image-embedding
# Out:
# Cloning into 'image-embedding'...
# remote: Enumerating objects: 85, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 359 (delta 44), reused 60 (delta 23), pack-reused 274
# Receiving objects: 100% (359/359), 578.64 KiB | 7.71 MiB/s, done.
# Resolving deltas: 100% (194/194), done.

# %%
# %cd image-embedding/
# Out:
# /content/image-embedding

# %%
# !git log
# Out:
# commit 34daf35019c5c8cfaa7197b29221c4a72c70b613 (HEAD -> master, origin/master, origin/HEAD)
# Author: aeg <aeg@amazon.com>
# Date:   Fri Aug 23 21:16:53 2019 +1000
#
#     Add ecr repo
#
# commit 4bd8c203254791e07ebde8698b7a6700f98f9831
# Author: aeg <aeg@amazon.com>
# Date:   Fri Aug 16 15:57:00 2019 +1000
#
#     Update tags
#
# commit 73d454e7b75a6a7978843a8cb838bfec6f4e4ea7
# Author: aeg <aeg@amazon.com>
# Date:   Fri Aug 16 14:51:29 2019 +1000
#
#     Fix version tag
#
# commit 5540119ee79c5cdc54a639a13b7636c9d11df35d
# Author: aeg <aeg@amazon.com>
# Date:   Fri Aug 16 14:02:47 2019 +1000
#
#     Add repo
#
# commit a7b5c140502de61a91706dbeabfb384d09ec676c
# Author: aeg <aeg@amazon.com>
# Date:   Fri Aug 16 13:49:58 2019 +1000
#
#     Add pytorch repo
#
# commit ffddbc9f1d92ea7bd2840a957cffd4d27c94f892
# Author: aeg <aeg@amazon.com>
# Date:   Fri Aug 16 11:26:36 2019 +1000
#
#     Fix region typo
#
# commit 7340e6e13bf8460686bf076d26787c929156079f
# ...

# %%
# !git checkout 83c6b443b0776a0777e9e840b32801d39d8fef27
# Out:
# Note: checking out '83c6b443b0776a0777e9e840b32801d39d8fef27'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at 83c6b44 Add links

# %%
ls -al
# Out:
# total 76
# drwxr-xr-x 6 root root  4096 Aug 27 05:04 ./
# drwxr-xr-x 1 root root  4096 Aug 27 05:04 ../
# drwxr-xr-x 8 root root  4096 Aug 27 05:04 .git/
# -rw-r--r-- 1 root root  1203 Aug 27 05:04 .gitignore
# -rw-r--r-- 1 root root 24824 Aug 27 05:04 ImageEmbedding.ipynb
# -rw-r--r-- 1 root root 11357 Aug 27 05:04 LICENSE
# drwxr-xr-x 2 root root  4096 Aug 27 05:04 loadtests/
# -rw-r--r-- 1 root root  1211 Aug 27 05:04 README.md
# drwxr-xr-x 3 root root  4096 Aug 27 05:04 src/
# drwxr-xr-x 5 root root  4096 Aug 27 05:04 tests/
# -rw-r--r-- 1 root root   203 Aug 27 05:04 .travis.yml

# %%
# %cd /content/image-embedding/tests
# Out:
# /content/image-embedding/tests

# %%
import requests
filename = "CAVIAR4REID.zip"
URL = "http://lorisbaz.github.io/datasets/"+filename
try:
  response = requests.get(URL,stream=True)
  print(response.status_code)
  if response.status_code == 200:
      with open("./"+filename, 'wb') as f:
          f.write(response.content) # 파일저장하기
except Exception as e:
  print(e)
# Out:
# 200

# %%
# !unzip CAVIAR4REID.zip
# Out:
# Archive:  CAVIAR4REID.zip
#    creating: CAVIARa/
#   inflating: CAVIARa/0001001.jpg
#   inflating: CAVIARa/0001002.jpg
#   inflating: CAVIARa/0001003.jpg
#   inflating: CAVIARa/0001004.jpg
#   inflating: CAVIARa/0001005.jpg
#   inflating: CAVIARa/0001006.jpg
#   inflating: CAVIARa/0001007.jpg
#   inflating: CAVIARa/0001008.jpg
#   inflating: CAVIARa/0001009.jpg
#   inflating: CAVIARa/0001010.jpg
#   inflating: CAVIARa/0002001.jpg
#   inflating: CAVIARa/0002002.jpg
#   inflating: CAVIARa/0002003.jpg
#   inflating: CAVIARa/0002004.jpg
#   inflating: CAVIARa/0002005.jpg
#   inflating: CAVIARa/0002006.jpg
#   inflating: CAVIARa/0002007.jpg
#   inflating: CAVIARa/0002008.jpg
#   inflating: CAVIARa/0002009.jpg
#   inflating: CAVIARa/0002010.jpg
#   inflating: CAVIARa/0003001.jpg
#   inflating: CAVIARa/0003002.jpg
#   inflating: CAVIARa/0003003.jpg
#   inflating: CAVIARa/0003004.jpg
#   inflating: CAVIARa/0003005.jpg
#   inflating: CAVIARa/0003006.jpg
#   inflating: CAVIARa/0003007.jpg
# ...

# %%
# %cd /content/image-embedding
# !python3 src/main_evaluate.py tests/CAVIARa
# Out:
# /content/image-embedding
# Runnning...
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# 100% 102502400/102502400 [00:01<00:00, 52972681.04it/s]
# tcmalloc: large alloc 5953601536 bytes == 0x10bce000 @  0x7febbbdbab6b 0x7febbbdda379 0x7feb69593e4e 0x7feb69595dca 0x7feb6a541d46 0x7feb6a1da3f9 0x7feb6a2cd1fc 0x7feb6a1e4ff6 0x7feb6a1e5678 0x7feb6a1e64cf 0x7feb6a072254 0x7feb6a4a4a70 0x7feb67eff139 0x7febb1d8a082 0x562433 0x57c2fe 0x4c277a 0x6053fc 0x579a82 0x4fa555 0x4f6128 0x4f42e7 0x5a1481 0x57c2fe 0x513601 0x57ec0c 0x4f88ba 0x4f98c7 0x4f7a28 0x4f876d 0x4f98c7
# ...

# %%
# !python src/main_evaluate.py tests/imagesCaviar
# Out:
# Runnning...
# Dataset <class 'torch.utils.data.dataloader.DataLoader'> , Result : 87.5

# %% [markdown]
# # 마무리
# - **모델** : pytorch에서 제공하는 resnet50
# - **데이터셋** : [Caviar Train](https://lorisbaz.github.io/caviar4reid.html) Dataset
# - resnet50 을 사용해 평가만 진행(학습x)
# - Caviar Train Dataset 전체로 평가 진행 **결과** : 51.819672131147534%
